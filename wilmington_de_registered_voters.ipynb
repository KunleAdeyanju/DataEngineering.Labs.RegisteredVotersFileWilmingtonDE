# %% [markdown]
# Import numpy and pandas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Using the bash magic command, view the list of files inside of the data directory.

# %% [markdown]
# You cant comment in the commandline it messes with it
#
# the comment: Use bash magic command to view list of files in the current directory

# %%
# %%bash
# ls
# Out:
# README.md
# data
# wilmington_de_registered_voters.ipynb

# %% [markdown]
# Load the csv file into a Pandas DataFrame.

# %%
# use read_csv to read in the data
reg_voter_df = pd.read_csv('./data/ActiveFile-Wilm1thru8-20191015.csv')
reg_voter_df.head()
# Out:
# /var/folders/98/9_hfbx1j37d31269lt42l9b40000gp/T/ipykernel_80482/4187342080.py:2: DtypeWarning: Columns (18,32,35,36,37,40,41,42,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   reg_voter_df = pd.read_csv('./data/ActiveFile-Wilm1thru8-20191015.csv')
#    UNIQUE-ID     LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH HOME-NO  \
# 0  100234840           ROY    BEVERLY        A    NaN           1952     320
# 1  100685572      WILLIAMS       LISA        F    NaN           1968     826
# 2  100485262        HARRIS     JOSEPH        A    III           1963    2616
# 3  100349191       LAMBORN     GERALD        V    NaN           1958     706
# 4  100394887  KRYSTOPOLSKI     ANDREW        R    NaN           1981    1009
#
#   HOME-APT   HOME-STREET            HOME-DEV  ... REF-HIST-5  MAIL-NO  \
# 0     #912      E 5TH ST  HERLIHY HOUSE APTS  ...        NaN      NaN
# 1      NaN      W 5TH ST                 NaN  ...        NaN      NaN
# ...

# %% [markdown]
# Display a list of columns in the DataFrame.

# %%
# display the columns
reg_voter_df.columns
# Out:
# Index(['UNIQUE-ID', 'LAST-NAME', 'FIRST-NAME', 'MID-INIT', 'SUFFIX',
#        'YEAR-OF-BIRTH', 'HOME-NO', 'HOME-APT', 'HOME-STREET', 'HOME-DEV',
#        'HOME-CITY', 'HOME-ZIPCODE', 'COUNTY', 'ED', 'RD', 'SD', 'CNLEVY',
#        'WILM', 'CODE-HOME-CITY', 'SCH-DIST', 'PARTY', 'DATE-REG', 'PP-HIST-1',
#        'PP-HIST-2', 'PR-HIST-1', 'PR-HIST-2', 'PR-HIST-3', 'GEN-HIST-1',
#        'GEN-HIST-2', 'GEN-HIST-3', 'GEN-HIST-4', 'GEN-HIST-5', 'SP-HIST-1',
#        'SP-HIST-2', 'SP-HIST-3', 'SCHL-HIST-1', 'SCHL-HIST-2', 'SCHL-HIST-3',
#        'SCHL-HIST-4', 'SCHL-HIST-5', 'REF-HIST-1', 'REF-HIST-2', 'REF-HIST-3',
#        'REF-HIST-4', 'REF-HIST-5', 'MAIL-NO', 'MAIL-APT', 'MAIL-STR',
#        'MAIL-CITY', 'MAIL-STATE', 'MAIL-ZIP', 'DATE-LAST-CHG', 'CODE-CHANGE',
#        'STATUS'],
#       dtype='object')

# %% [markdown]
# What is the shape of this DataFrame? How many columns does each row have? How many rows are there?

# %%
# shape of the dataFrame
reg_voter_df.shape
# Out:
# (51909, 54)

# %% [markdown]
# # HOME ZIP CODE

# %% [markdown]
# Group objects using the HOME-ZIPCODE column. Assign the value to a variable called grouped_zc.
# [Pandas Groupby User Guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html)

# %%
# group objects, and assign the value to a variable called grouped_zc
grouped_zc = reg_voter_df.groupby('HOME-ZIPCODE')
grouped_zc.head(5)
# Out:
#       UNIQUE-ID     LAST-NAME   FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH  \
# 0     100234840           ROY      BEVERLY        A    NaN           1952
# 1     100685572      WILLIAMS         LISA        F    NaN           1968
# 2     100485262        HARRIS       JOSEPH        A    III           1963
# 3     100349191       LAMBORN       GERALD        V    NaN           1958
# 4     100394887  KRYSTOPOLSKI       ANDREW        R    NaN           1981
# 5     100604371        CARTER      MILDRED        P    NaN           1923
# 6     100046407         VELEZ       EDISON      NaN    NaN           1939
# 7     100462556        DORSEY      BERNARD        S    NaN           1941
# 8     100377694        KOVACH        KAREN        L    NaN           1966
# 9     100537362        HARRIS        DAVID        B    NaN           1974
# 10    100737992       WALLACE     JONATHAN      NaN    NaN           1968
# 11    100664028     MCKENNIES          RON        T    NaN           1955
# ...

# %% [markdown]
# What type of object is grouped_zc?

# %%
# type of grouped_zc
type(grouped_zc)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# DataFrameGroupBy objects contain a groups attribute. Display the value of the groups attribute belonging to the grouped_zc object.

# %%
# display the value of the groups attribute belonging to grouped_zc
'''
 display the value of the groups attribute belonging to grouped_zcThe groups attribute is a dictionary
   that maps each group key (e.g., a unique value in the column you grouped by) to the 
   indices (row labels) of the rows that belong to that group.
'''
grouped_zc.groups
# Out:
# {19801: [0, 1, 10, 12, 13, 15, 16, 20, 24, 34, 55, 56, 57, 58, 62, 64, 65, 67, 79, 92, 94, 95, 98, 102, 103, 110, 118, 120, 121, 129, 131, 136, 146, 149, 151, 157, 158, 173, 174, 180, 184, 188, 194, 197, 198, 202, 203, 210, 211, 215, 222, 223, 228, 229, 233, 241, 242, 263, 278, 281, 282, 284, 285, 286, 287, 288, 291, 292, 293, 294, 300, 301, 302, 310, 311, 312, 316, 317, 321, 322, 323, 324, 327, 333, 334, 336, 337, 339, 340, 343, 344, 345, 346, 347, 348, 349, 354, 357, 365, 372, ...], 19802: [3, 5, 11, 21, 29, 30, 31, 38, 39, 40, 45, 46, 51, 52, 53, 54, 59, 60, 61, 68, 69, 70, 76, 77, 78, 80, 84, 85, 88, 89, 91, 97, 99, 100, 101, 108, 109, 116, 122, 123, 124, 125, 130, 134, 135, 138, 139, 140, 143, 144, 145, 148, 154, 155, 156, 160, 162, 163, 172, 181, 186, 187, 195, 196, 200, 201, 205, 206, 207, 208, 213, 214, 220, 225, 226, 239, 240, 243, 245, 246, 250, 251, 252, 265, 270, 273, 275, 276, 277, 290, 299, 307, 308, 309, 313, 314, 315, 318, 319, 320, ...], 19805: [4, 6, 7, 8, 14, 17, 1
# ...

# %% [markdown]
# Invoke the size method on the grouped_zc object to find out how many items are associated with each zip code.

# %%
# 
grouped_zc.size()
# Out:
# HOME-ZIPCODE
# 19801    10730
# 19802    17182
# 19805    15548
# 19806     8326
# 19807      123
# dtype: int64

# %% [markdown]
# Use a magic command so that matplotlib graphics will display inline.

# %%
# %matplotlib inline

# %% [markdown]
# Create a pie chart illustrating the number of voters per zip code.

# %%
# 
grouped_zc.size().plot.pie(title='Number of Voters by Zip Code',
                          figsize=(12, 8),
                          fontsize=14,
                          legend=True,
                          colormap='viridis')
# Out:
# <Axes: title={'center': 'Number of Voters by Zip Code'}>

# %% [markdown]
# # YEAR OF BIRTH

# %% [markdown]
# Group objects by the YEAR-OF-BIRTH column. Assign the value to an object called "grouped_yob".

# %%
# 
grouped_yob = reg_voter_df.groupby('YEAR-OF-BIRTH')
grouped_yob.head(5)
# Out:
#        UNIQUE-ID     LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH  \
# 0      100234840           ROY    BEVERLY        A    NaN           1952
# 1      100685572      WILLIAMS       LISA        F    NaN           1968
# 2      100485262        HARRIS     JOSEPH        A    III           1963
# 3      100349191       LAMBORN     GERALD        V    NaN           1958
# 4      100394887  KRYSTOPOLSKI     ANDREW        R    NaN           1981
# ...          ...           ...        ...      ...    ...            ...
# 22219  100737706         BROWN     BEULAH      NaN    NaN           1919
# 23508  101151582        MCNEIL       LOIS        R    NaN           1919
# 42509  100435977         MATAS    ELEANOR        B    NaN           1919
# 49249  101092654       KENNEDY     JORDAN        D    NaN           1900
# 49808  100452120       RISPOLI       ANNA        M    NaN           1916
#
#       HOME-NO HOME-APT     HOME-STREET            HOME-DEV  ... REF-HIST-5  \
# ...

# %% [markdown]
# Display the value of the groups attribute belonging the grouped_yob object.

# %%
# 
grouped_yob.groups
# Out:
# {1900: [49249], 1912: [5607], 1915: [6983, 7233], 1916: [2773, 16265, 49808], 1917: [2425, 12614], 1918: [7276, 7318, 9601, 14196], 1919: [12435, 17404, 22219, 23508, 42509], 1920: [271, 350, 534, 3468, 3541, 3909, 5485, 5606, 7071, 13684, 14831, 15495, 17447, 22093, 24793, 24934, 26266, 27799, 37052, 37182, 38014, 42055, 47857], 1921: [977, 1048, 1905, 3326, 4066, 7893, 12729, 14907, 16396, 17176, 18116, 18736, 22236, 23100, 24936, 25142, 25335, 25632, 26505, 26592, 28858, 37963, 39804, 41209, 48463, 49695], 1922: [159, 3071, 3299, 4044, 4159, 6558, 9461, 13850, 16113, 16180, 16239, 18005, 20665, 22237, 25317, 30000, 32684, 35901, 37097, 37382, 40184, 41698, 44190, 48984, 49009, 49388, 49791, 50729, 51237], 1923: [5, 1846, 2795, 3753, 4129, 4308, 5505, 6225, 7259, 13599, 14331, 14650, 15951, 16891, 18223, 18380, 22277, 22323, 25012, 25356, 25474, 25523, 31360, 33616, 39803, 41074, 41576, 41661, 41917, 42635, 43422, 49213], 1924: [426, 766, 1311, 1446, 2011, 2461, 2691, 4064, 4106, 5
# ...

# %% [markdown]
# Select the object for the row indicating that the voter was born in 1900.

# %%
# select the object for the row indicating that the voter was born in 1900
# grouped_yob.groups[1900] gives you the
grouped_yob.get_group(1900)
# Out:
#        UNIQUE-ID LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH HOME-NO  \
# 49249  101092654   KENNEDY     JORDAN        D    NaN           1900     724
#
#       HOME-APT     HOME-STREET HOME-DEV  ... REF-HIST-5  MAIL-NO MAIL-APT  \
# 49249      NaN  N BANCROFT PKY      NaN  ...        NaN      NaN      NaN
#
#        MAIL-STR  MAIL-CITY  MAIL-STATE  MAIL-ZIP  DATE-LAST-CHG CODE-CHANGE  \
# 49249       NaN        NaN         NaN       NaN       20170731          P6
#
#       STATUS
# 49249      I
#
# [1 rows x 54 columns]

# %% [markdown]
# Graph a histogram to  illustrate the age distribution of voters in this dataset. Ty using different values for the bins attribute of the histogram.

# %%
grouped_yob.size()
# Out:
# YEAR-OF-BIRTH
# 1900      1
# 1912      1
# 1915      2
# 1916      3
# 1917      2
#        ...
# 1998    786
# 1999    719
# 2000    717
# 2001    575
# 2002    395
# Length: 90, dtype: int64

# %%
# 
grouped_yob.size().plot.hist(y= 'YEAR-OF-BIRTH',title='Number of Voters by Year of Birth',)
# Out:
# <Axes: title={'center': 'Number of Voters by Year of Birth'}, ylabel='Frequency'>

# %% [markdown]
# # PARTY

# %% [markdown]
# Group objects using the PARTY column. Assign the value to a variable called grouped_p.

# %%
# 
grouped_p = reg_voter_df.groupby('PARTY')
grouped_p.head(5)
# Out:
#        UNIQUE-ID     LAST-NAME   FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH  \
# 0      100234840           ROY      BEVERLY        A    NaN           1952
# 1      100685572      WILLIAMS         LISA        F    NaN           1968
# 2      100485262        HARRIS       JOSEPH        A    III           1963
# 3      100349191       LAMBORN       GERALD        V    NaN           1958
# 4      100394887  KRYSTOPOLSKI       ANDREW        R    NaN           1981
# ...          ...           ...          ...      ...    ...            ...
# 17347  101072610    IADISERNIA        KATIE        R    NaN           1984
# 18075  101083789         GURKA        BRIAN        J    NaN           1990
# 18799  100946353         BROWN      BREANNA        T    NaN           1994
# 19128  100380254          LUPI     PATRICIA        L    NaN           1971
# 22522  101066289         NEILL  CHRISTOPHER      NaN    NaN           1985
#
# ...

# %% [markdown]
# Display the value of the groups attribute belonging to the grouped_p object.

# %%
# 
grouped_p.groups
# Out:
# {'A': [2578, 2639, 3108, 5105, 10230, 10491, 10842, 11620, 12162, 12413, 12417, 12454, 12507, 12522, 12810, 12831, 14469, 14507, 15144, 15382, 15509, 16858, 17075, 17173, 17309, 19466, 19884, 20846, 21086, 21459, 22451, 22645, 22746, 23739, 24604, 24664, 24665, 24691, 26662, 28775, 30455, 30510, 30976, 34065, 34903, 36518, 44984, 45851, 46837, 49699, 51736, 51830], 'B': [11866, 11867, 11869, 11870, 11873, 11875, 11876, 11880, 11882, 11883, 11884, 11885, 11886, 11887, 11888, 11889, 11890, 11891, 11892, 11893, 11895, 11896, 11898, 11899, 11900, 11901, 11902, 11903, 11904, 11905, 11906, 11908, 11909, 11910, 11911, 11913, 11914, 11915, 11916, 11917, 11918, 11920, 11924, 11925, 11926, 11927, 11929, 11930, 11932, 11933, 11934, 11940, 11941, 11942, 11951, 11952, 11953, 11956, 11958, 11960, 11961, 11965, 11966, 11968, 11971, 11973, 11974, 11977, 11980, 11981, 11982, 11984, 11987, 11988, 11990, 11991, 11992, 11994, 11999, 12001, 12002, 12003, 12004, 12006, 12008, 12009, 12012, 12014, 12015, 1
# ...

# %% [markdown]
# Invoke the size method on the grouped_p object to find out how many items are associated with each party.

# %%
# 
grouped_p.size()
# Out:
# PARTY
# A       52
# B      441
# D    38020
# E       30
# G       42
# H       82
# I     7670
# J      161
# L       98
# M        1
# O       33
# Q       17
# R     4851
# T       14
# V       11
# W      333
# Y       14
# Z       39
# dtype: int64

# %% [markdown]
# Create a bar chart to visualize the number of voters associated with each party.

# %%
# 
grouped_p.size().plot.bar(title='Number of Voters by Party')
# Out:
# <Axes: title={'center': 'Number of Voters by Party'}, xlabel='PARTY'>

# %% [markdown]
# # Merging Two DataFrames

# %% [markdown]
# Using the data from the documentation, create a Pandas DataFrame that contains the party code and the corresponding legal name for each party.

# %%
legal_names = {'A' : ['AMERICAN'], 'B' : ['AMERICAN DELTA'], 'D' : ['DEMONCRAT PARTY'], 'E' : ['LIBERAL'], 'G' : ['NON PARTISAN'], \
               'H' : ['GREEN PARTY'], 'I' : ['UNAFFILIATED'], 'J' : ['WORKING FAMILIES PARTY'], 'L' : ['LIBERTARIAN PARTY'], \
                'M' : ['REFORM PARTY'], 'O' : ['OTHERS/ALL OTHER PARTIES'], 'Q' : ['CONSTITUTION PARTY'], 'R' : ['REPUBLICAN PARTY'], \
                    'T' : ['CONSERVATIVE'], 'V' : ['NATURAL LAW PARTY'], 'W' : ['INDEPENDENT PARTY'], 'Y' : ['THE BLUE ENIGMA PARTY'], \
                        'Z' : ['SOCIALIST WORKERS PARTY']}
legal_names
# Out:
# {'A': ['AMERICAN'],
#  'B': ['AMERICAN DELTA'],
#  'D': ['DEMONCRAT PARTY'],
#  'E': ['LIBERAL'],
#  'G': ['NON PARTISAN'],
#  'H': ['GREEN PARTY'],
#  'I': ['UNAFFILIATED'],
#  'J': ['WORKING FAMILIES PARTY'],
#  'L': ['LIBERTARIAN PARTY'],
#  'M': ['REFORM PARTY'],
#  'O': ['OTHERS/ALL OTHER PARTIES'],
#  'Q': ['CONSTITUTION PARTY'],
#  'R': ['REPUBLICAN PARTY'],
#  'T': ['CONSERVATIVE'],
#  'V': ['NATURAL LAW PARTY'],
#  'W': ['INDEPENDENT PARTY'],
#  'Y': ['THE BLUE ENIGMA PARTY'],
#  'Z': ['SOCIALIST WORKERS PARTY']}

# %%
df_legal_names = pd.DataFrame(legal_names)

# %%
df_legal_names.T
# Out:
#                           0
# A                  AMERICAN
# B            AMERICAN DELTA
# D           DEMONCRAT PARTY
# E                   LIBERAL
# G              NON PARTISAN
# H               GREEN PARTY
# I              UNAFFILIATED
# J    WORKING FAMILIES PARTY
# L         LIBERTARIAN PARTY
# M              REFORM PARTY
# O  OTHERS/ALL OTHER PARTIES
# Q        CONSTITUTION PARTY
# R          REPUBLICAN PARTY
# T              CONSERVATIVE
# V         NATURAL LAW PARTY
# W         INDEPENDENT PARTY
# Y     THE BLUE ENIGMA PARTY
# Z   SOCIALIST WORKERS PARTY

# %% [markdown]
# Create a Pandas DataFrame that contains the Party code and the corresponding number of registered voters for said party.

# %%
# Create DataFrame df_party_counts here 
df_party_counts = pd.DataFrame(grouped_p.size())

# %%
df_party_counts
# Out:
#            0
# PARTY
# A         52
# B        441
# D      38020
# E         30
# G         42
# H         82
# I       7670
# J        161
# L         98
# M          1
# O         33
# Q         17
# R       4851
# T         14
# V         11
# W        333
# Y         14
# Z         39

# %% [markdown]
# Merge the two DataFrames.

# %%
# Merge DataFrame here 
#df_party_counts['PARTY_NAME'] = df_party_countsdf_legal_names.T.values()
df_party_names_count = pd.concat([df_party_counts, df_legal_names.T], axis=1)

# %%
# Display new DataFrame here
df_party_names_count.columns = ['PARTY_COUNT', 'PARTY_NAME']
df_party_names_count = df_party_names_count.reindex(columns=['PARTY_NAME', 'PARTY_COUNT'])
df_party_names_count
# Out:
#                  PARTY_NAME  PARTY_COUNT
# A                  AMERICAN           52
# B            AMERICAN DELTA          441
# D           DEMONCRAT PARTY        38020
# E                   LIBERAL           30
# G              NON PARTISAN           42
# H               GREEN PARTY           82
# I              UNAFFILIATED         7670
# J    WORKING FAMILIES PARTY          161
# L         LIBERTARIAN PARTY           98
# M              REFORM PARTY            1
# O  OTHERS/ALL OTHER PARTIES           33
# Q        CONSTITUTION PARTY           17
# R          REPUBLICAN PARTY         4851
# T              CONSERVATIVE           14
# V         NATURAL LAW PARTY           11
# W         INDEPENDENT PARTY          333
# Y     THE BLUE ENIGMA PARTY           14
# Z   SOCIALIST WORKERS PARTY           39

# %% [markdown]
# Create a bar graph again but using the legal name for each party as the value on the x axes.

# %%
# 
df_party_names_count.plot.bar(x='PARTY_NAME', y='PARTY_COUNT', title='Number of Voters by Party Name', figsize=(12, 8), fontsize=14, legend=True, colormap='viridis')
# Out:
# <Axes: title={'center': 'Number of Voters by Party Name'}, xlabel='PARTY_NAME'>
